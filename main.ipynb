# %%
import pandas as pd
from tqdm import tqdm
import pickle
from glob import glob
from nltk.tokenize import sent_tokenize
from collections import Counter, defaultdict
# from google.colab import drive
# drive.mount('content/')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. pickle로 저장한 pybliometrics 논문 객체를 불러와서 BERT 학습할 Corpus 구축

# %%
# Integrate dictionaries of pybliometrics class
files = glob(r"D:\myproject\research_work\citation_prediction\rsc\preparation_data\*.pickle")
data_dict = {}
for file in files:
    with open(file, 'rb') as f:   
        data_dict.update(pickle.load(f))

# %%
# Define functions for data preprocessing
def copyright_tag_remove(sentence): # Remove copyright tag in abstract
    # Remove from © to end
    front_idx = sentence.find('©')
    if front_idx == -1:
        return sentence
    end_idx = len(sentence)
    erase_target = sentence[front_idx:end_idx]
    replace_sentence = sentence.replace(erase_target, "")
    # Remove 'Copyright' specified
    replace_sentence = replace_sentence.replace('Copyright', "")
    return  replace_sentence

def sentence_tokenize(sentences): # Seperate corpus in sentences
    st = sent_tokenize(sentences)
    if len(st) == 1:
        return sentences
    else:
        return '\n'.join(st)

# Define functions for data postprocessing
def build_token_dict_from_vocabs(vocab_path):
    token_dict = {}
    with open(vocab_path, 'r', encoding='utf-8') as f:
        for line in f.readlines():
            token = line.strip()
            token_dict[token] = len(token_dict)
    return token_dict

# %%
# Make dataframe from class dictionary data
df = pd.DataFrame()
for obj in tqdm(data_dict.values()):
    df = df.append(pd.DataFrame(obj.results))

# Extract corpus needed from full dataframe
df_treated = df.dropna(subset=['title', 'description'])
df_treated = df_treated.reset_index(drop=True)
corpus = df_treated[['title', 'description']]

# Preprocessing
corpus['description'] = corpus['description'].apply(copyright_tag_remove)

# %%
# Save to corpus.text from dataframe corpus
with open("rsc/conf/corpus/corpus.txt", 'w', encoding='utf-8') as f:
    for i in tqdm(range(len(corpus))):
        # Title 이 2개 문장 이상일 경우를 대비하여 문장 토큰화
        f.write(sentence_tokenize(corpus.loc[i, 'title']))
        f.write("\n")
        f.write(sentence_tokenize(corpus.loc[i, 'description']))
        f.write("\n\n")

# %%
# Make vocab.txt
# !python src/make_vocab/wordpiece.py --corpus=rsc/conf/corpus/corpus.txt --iter=1000 --fname=rsc/conf/vocab/vocab.txt
# Out:
# ^C

# %% [markdown]
# # 2. 구축한 Vocab을 통해 학습 데이터 생성

# %%
token_dict = build_token_dict_from_vocabs('rsc/conf/vocab/vocab.txt')
len(token_dict)

# %%
token_dict
# Out:
# {'[PAD]': 0,
#  '[unused1]': 1,
#  '[unused2]': 2,
#  '[unused3]': 3,
#  '[unused4]': 4,
#  '[unused5]': 5,
#  '[unused6]': 6,
#  '[unused7]': 7,
#  '[unused8]': 8,
#  '[unused9]': 9,
#  '[unused10]': 10,
#  '[unused11]': 11,
#  '[unused12]': 12,
#  '[unused13]': 13,
#  '[unused14]': 14,
#  '[unused15]': 15,
#  '[unused16]': 16,
#  '[unused17]': 17,
#  '[unused18]': 18,
#  '[unused19]': 19,
#  '[unused20]': 20,
#  '[unused21]': 21,
#  '[unused22]': 22,
#  '[unused23]': 23,
#  '[unused24]': 24,
#  '[unused25]': 25,
#  '[unused26]': 26,
#  '[unused27]': 27,
#  '[unused28]': 28,
#  '[unused29]': 29,
#  '[unused30]': 30,
#  '[unused31]': 31,
#  '[unused32]': 32,
#  '[unused33]': 33,
#  '[unused34]': 34,
#  '[unused35]': 35,
#  '[unused36]': 36,
#  '[unused37]': 37,
#  '[unused38]': 38,
#  '[unused39]': 39,
#  '[unused40]': 40,
#  '[unused41]': 41,
#  '[unused42]': 42,
#  '[unused43]': 43,
#  '[unused44]': 44,
#  '[unused45]': 45,
#  '[unused46]': 46,
#  '[unused47]': 47,
#  '[unused48]': 48,
#  '[unused49]': 49,
#  '[unused50]': 50,
#  '[unused51]': 51,
#  '[unused52]': 52,
#  '[unused53]': 53,
#  '[unused54]': 54,
#  '[unused55]': 55,
#  '[unused56]': 56,
#  '[unused57]': 57,
#  '[unused58]': 58,
#  '[unused59]': 59,
#  '[unused60]': 60,
#  '[unused61]': 61,
#  '[unused62]': 62,
#  '[unused63]': 63,
#  '[unused64]': 64,
#  '[unused65]': 65,
#  '[unused66]': 66,
#  '[unused67]': 67,
#  '[unused68]': 68,
#  '[unused69]': 69,
#  '[unused70]': 70,
#  '[unused71]': 71,
#  '[unused72]': 72,
#  '[unused73]': 73,
#  '[unused74]': 74,
#  '[unused75]': 75,
#  '[unused76]': 76,
#  '[unused77]': 77,
#  '[unused78]': 78,
#  '[unused79]': 79,
#  '[unused80]': 80,
#  '[unused81]': 81,
#  '[unused82]': 82,
#  '[unused83]': 83,
#  '[unused84]': 84,
#  '[unused85]': 85,
#  '[unused86]': 86,
#  '[unused87]': 87,
#  '[unused88]': 88,
#  '[unused89]': 89,
#  '[unused90]': 90,
#  '[unused91]': 91,
#  '[unused92]': 92,
#  '[unused93]': 93,
#  '[unused94]': 94,
#  '[unused95]': 95,
#  '[unused96]': 96,
#  '[unused97]': 97,
#  '[unused98]': 98,
#  '[unused99]': 99,
#  '[UNK]': 100,
#  '[CLS]': 101,
#  '[SEP]': 102,
#  '[MASK]': 103,
#  'the': 104,
#  'of': 105,
#  '##s': 106,
#  '##.': 107,
#  'and': 108,
#  '##,': 109,
#  'a': 110,
#  'to': 111,
#  'in': 112,
#  '##-': 113,
#  'is': 114,
#  'for': 115,
#  '##al': 116,
#  '##y': 117,
#  '##ing': 118,
#  'The': 119,
#  'p': 120,
#  '##e': 121,
#  'with': 122,
#  '##t': 123,
#  'on': 124,
#  '##ation': 125,
#  '##i': 126,
#  'are': 127,
#  's': 128,
#  '##c': 129,
#  'that': 130,
#  '(': 131,
#  '##g': 132,
#  'l': 133,
#  'as': 134,
#  '##o': 135,
#  '##l': 136,
#  'an': 137,
#  '##d': 138,
#  '##)': 139,
#  '##ed': 140,
#  'c': 141,
#  'by': 142,
#  'A': 143,
#  't': 144,
#  '##u': 145,
#  'g': 146,
#  '##a': 147,
#  'r': 148,
#  '##n': 149,
#  'f': 150,
#  'b': 151,
#  'be': 152,
#  'e': 153,
#  '##ve': 154,
#  'S': 155,
#  'con': 156,
#  'this': 157,
#  '##in': 158,
#  '##s.': 159,
#  '##b': 160,
#  'In': 161,
#  '##S': 162,
#  '##p': 163,
#  '##es': 164,
#  '##ly': 165,
#  '##ic': 166,
#  '##or': 167,
#  '##er': 168,
#  '##C': 169,
#  'M': 170,
#  '##A': 171,
#  'C': 172,
#  'we': 173,
#  '##it': 174,
#  '##M': 175,
#  'model': 176,
#  'co': 177,
#  '##f': 178,
#  '##ar': 179,
#  '##m': 180,
#  '##k': 181,
#  '##ment': 182,
#  '##s,': 183,
#  'which': 184,
#  'from': 185,
#  'can': 186,
#  'v': 187,
#  'system': 188,
#  '##ol': 189,
#  'st': 190,
#  '##D': 191,
#  'P': 192,
#  '##ent': 193,
#  '##P': 194,
#  '##ate': 195,
#  'de': 196,
#  '##ur': 197,
#  '##an': 198,
#  'D': 199,
#  '##E': 200,
#  'w': 201,
#  'This': 202,
#  '##ce': 203,
#  '##re': 204,
#  '##I': 205,
#  '##able': 206,
#  'ex': 207,
#  '##ri': 208,
#  '##at': 209,
#  'data': 210,
#  'pro': 211,
#  '##ity': 212,
#  're': 213,
#  'using': 214,
#  'proposed': 215,
#  '##R': 216,
#  'method': 217,
#  'h': 218,
#  'results': 219,
#  'F': 220,
#  'R': 221,
#  'm': 222,
#  '##T': 223,
#  'E': 224,
#  '##N': 225,
#  '##ay': 226,
#  '##w': 227,
#  'based': 228,
#  '##tion': 229,
#  'paper': 230,
#  'control': 231,
#  'B': 232,
#  '##ding': 233,
#  '##ated': 234,
#  '##en': 235,
#  '##0': 236,
#  '##as': 237,
#  'was': 238,
#  'inter': 239,
#  'has': 240,
#  'un': 241,
#  '##O': 242,
#  '##ch': 243,
#  '##ip': 244,
#  'used': 245,
#  'or': 246,
#  '##ul': 247,
#  '##h': 248,
#  '##ric': 249,
#  'at': 250,
#  'show': 251,
#  '##ro': 252,
#  'We': 253,
#  '##L': 254,
#  '##F': 255,
#  'N': 256,
#  'ac': 257,
#  'have': 258,
#  'rel': 259,
#  'T': 260,
#  'design': 261,
#  'performance': 262,
#  'algorithm': 263,
#  'en': 264,
#  '##is': 265,
#  'it': 266,
#  'O': 267,
#  '##ure': 268,
#  '##ain': 269,
#  '##x': 270,
#  'L': 271,
#  '##1': 272,
#  '##age': 273,
#  '##ance': 274,
#  '##ad': 275,
#  '##r': 276,
#  '##id': 277,
#  '##um': 278,
#  '##2': 279,
#  '##:': 280,
#  'been': 281,
#  '##th': 282,
#  '##se': 283,
#  '##ra': 284,
#  '##ative': 285,
#  '##v': 286,
#  'approach': 287,
#  'ar': 288,
#  'two': 289,
#  '##ter': 290,
#  '##ations': 291,
#  '##il': 292,
#  'sh': 293,
#  '##ous': 294,
#  'high': 295,
#  'time': 296,
#  'were': 297,
#  'H': 298,
#  '##sion': 299,
#  '##us': 300,
#  'new': 301,
#  '##ability': 302,
#  'd': 303,
#  'i': 304,
#  'analysis': 305,
#  '##ary': 306,
#  '##ating': 307,
#  '##ap': 308,
#  '1': 309,
#  '##ical': 310,
#  'under': 311,
#  '##st': 312,
#  'problem': 313,
#  '##ator': 314,
#  'different': 315,
#  '##ge': 316,
#  'set': 317,
#  'study': 318,
#  'par': 319,
#  'also': 320,
#  'man': 321,
#  '##ant': 322,
#  'cont': 323,
#  'n': 324,
#  'per': 325,
#  'tra': 326,
#  'ch': 327,
#  'between': 328,
#  '##V': 329,
#  'G': 330,
#  'learning': 331,
#  '##ial': 332,
#  'use': 333,
#  'such': 334,
#  'not': 335,
#  '##ual': 336,
#  '##ies': 337,
#  '##et': 338,
#  '##/': 339,
#  'out': 340,
#  '##ab': 341,
#  '##B': 342,
#  'their': 343,
#  '2': 344,
#  '##ail': 345,
#  '##-based': 346,
#  'function': 347,
#  'information': 348,
#  'over': 349,
#  '##ving': 350,
#  'these': 351,
#  'sub': 352,
#  'th': 353,
#  'I': 354,
#  'di': 355,
#  'al': 356,
#  '##G': 357,
#  'application': 358,
#  'work': 359,
#  'fuzzy': 360,
#  'o': 361,
#  'engine': 362,
#  'U': 363,
#  '##le': 364,
#  'its': 365,
#  '##de': 366,
#  'oper': 367,
#  '##od': 368,
#  '##ack': 369,
#  '##ization': 370,
#  'trans': 371,
#  '##ular': 372,
#  'more': 373,
#  'qu': 374,
#  '##ight': 375,
#  'network': 376,
#  'real': 377,
#  '##ati': 378,
#  'systems': 379,
#  '##un': 380,
#  'vari': 381,
#  'evalu': 382,
#  '##ts': 383,
#  '##am': 384,
#  'test': 385,
#  'incre': 386,
#  '##ted': 387,
#  '##ized': 388,
#  '##on': 389,
#  '##ved': 390,
#  '##5': 391,
#  'into': 392,
#  '##ver': 393,
#  '##ition': 394,
#  '##el': 395,
#  'pl': 396,
#  '##ut': 397,
#  'fin': 398,
#  'W': 399,
#  '##ib': 400,
#  'sp': 401,
#  'he': 402,
#  '##act': 403,
#  '##ard': 404,
#  'vehicle': 405,
#  '##co': 406,
#  '##ational': 407,
#  'ad': 408,
#  '##ning': 409,
#  'other': 410,
#  'one': 411,
#  '##ion': 412,
#  '##up': 413,
#  '##king': 414,
#  "##'s": 415,
#  '##iti': 416,
#  '##ll': 417,
#  'obj': 418,
#  '##).': 419,
#  'sim': 420,
#  'our': 421,
#  'desc': 422,
#  '##to': 423,
#  'pre': 424,
#  '##ments': 425,
#  '##ac': 426,
#  'dynamic': 427,
#  '##cal': 428,
#  'both': 429,
#  '##ot': 430,
#  '##ti': 431,
#  'number': 432,
#  '##ide': 433,
#  'spec': 434,
#  '##ature': 435,
#  '##ize': 436,
#  'sur': 437,
#  '##H': 438,
#  'chan': 439,
#  'V': 440,
#  'cap': 441,
#  '##ult': 442,
#  '##ir': 443,
#  'than': 444,
#  'well': 445,
#  '##ence': 446,
#  '##3': 447,
#  'dri': 448,
#  'typ': 449,
#  '##ded': 450,
#  '##ine': 451,
#  '##9': 452,
#  'equ': 453,
#  'each': 454,
#  '##ast': 455,
#  'through': 456,
#  '##ear': 457,
#  'developed': 458,
#  '##z': 459,
#  '##),': 460,
#  '##ite': 461,
#  '##ting': 462,
#  '##ound': 463,
#  'all': 464,
#  '##ility': 465,
#  '##ron': 466,
#  'fuel': 467,
#  'order': 468,
#  'It': 469,
#  '3': 470,
#  'methods': 471,
#  'process': 472,
#  '##istic': 473,
#  'car': 474,
#  '##%': 475,
#  'An': 476,
#  'fi': 477,
#  'paper,': 478,
#  'inclu': 479,
#  '##ect': 480,
#  '##ust': 481,
#  'comp': 482,
#  '##ew': 483,
#  'gro': 484,
#  '##j': 485,
#  'solution': 486,
#  'will': 487,
#  '##ther': 488,
#  '##op': 489,
#  'power': 490,
#  'su': 491,
#  '##;': 492,
#  'j': 493,
#  'cl': 494,
#  'improve': 495,
#  '##ort': 496,
#  '##ural': 497,
#  'sche': 498,
#  'research': 499,
#  '##pen': 500,
#  '##oint': 501,
#  '##ag': 502,
#  'int': 503,
#  'comput': 504,
#  '##put': 505,
#  'expl': 506,
#  'presented': 507,
#  '##qu': 508,
#  'task': 509,
#  '##ulation': 510,
#  'investig': 511,
#  'when': 512,
#  'some': 513,
#  '##ree': 514,
#  '##our': 515,
#  'sol': 516,
#  'valu': 517,
#  '##os': 518,
#  '##ities': 519,
#  'le': 520,
#  'present': 521,
#  'models': 522,
#  'program': 523,
#  'development': 524,
#  'achi': 525,
#  'ab': 526,
#  '##ves': 527,
#  'comb': 528,
#  'produc': 529,
#  'fe': 530,
#  'up': 531,
#  'level': 532,
#  '##ble': 533,
#  'ma': 534,
#  '##4': 535,
#  '##out': 536,
#  '##y.': 537,
#  'complex': 538,
#  'measure': 539,
#  'To': 540,
#  'image': 541,
#  '##00': 542,
#  'first': 543,
#  '##all': 544,
#  'strat': 545,
#  '##fer': 546,
#  '##ry': 547,
#  '##im': 548,
#  'form': 549,
#  'elect': 550,
#  '##ig': 551,
#  'se': 552,
#  '##ution': 553,
#  '##ful': 554,
#  'experiment': 555,
#  '##ame': 556,
#  'reg': 557,
#  'identi': 558,
#  'simulation': 559,
#  'Ex': 560,
#  'three': 561,
#  'k': 562,
#  'y': 563,
#  'intro': 564,
#  '##U': 565,
#  '##per': 566,
#  'partic': 567,
#  '##der': 568,
#  '##ct': 569,
#  'optimization': 570,
#  'det': 571,
#  'multi-': 572,
#  'but': 573,
#  'discus': 574,
#  'ver': 575,
#  'features': 576,
#  '##ness': 577,
#  '##tive': 578,
#  'rec': 579,
#  '##ation.': 580,
#  '##6': 581,
#  'most': 582,
#  'robot': 583,
#  '##ia': 584,
#  '##ication': 585,
#  'user': 586,
#  '##ater': 587,
#  'environment': 588,
#  '##oy': 589,
#  'fl': 590,
#  '##ces': 591,
#  '##sive': 592,
#  '##ally': 593,
#  '##ses': 594,
#  'consider': 595,
#  '##8': 596,
#  'state': 597,
#  'neural': 598,
#  '##og': 599,
#  'integ': 600,
#  'significant': 601,
#  'mat': 602,
#  '##ase': 603,
#  '##sing': 604,
#  '##pl': 605,
#  'implement': 606,
#  'general': 607,
#  'cost': 608,
#  '##ke': 609,
#  '##ec': 610,
#  'only': 611,
#  'human': 612,
#  'air': 613,
#  '##y,': 614,
#  '##ext': 615,
#  'ne': 616,
#  'compared': 617,
#  'propose': 618,
#  'low': 619,
#  '##sed': 620,
#  'Con': 621,
#  'go': 622,
#  'decision': 623,
#  '##ell': 624,
#  'hy': 625,
#  '##ds': 626,
#  'where': 627,
#  '##ub': 628,
#  '##ling': 629,
#  'represent': 630,
#  'dire': 631,
#  '##action': 632,
#  '##ware': 633,
#  '##ased': 634,
#  'structure': 635,
#  '##ining': 636,
#  '##sity': 637,
#  'op': 638,
#  'sy': 639,
#  'cy': 640,
#  'knowledge': 641,
#  'experimental': 642,
#  'studi': 643,
#  'ran': 644,
#  '##rid': 645,
#  '##ob': 646,
#  'However,': 647,
#  'classification': 648,
#  'obtained': 649,
#  'val': 650,
#  '##ix': 651,
#  'framework': 652,
#  'speed': 653,
#  '##e.': 654,
#  '##ates': 655,
#  '##ject': 656,
#  'large': 657,
#  'adap': 658,
#  'non': 659,
#  'engineering': 660,
#  'av': 661,
#  '##ration': 662,
#  '##and': 663,
#  'plan': 664,
#  'during': 665,
#  '##ose': 666,
#  'characteristic': 667,
#  'important': 668,
#  'component': 669,
#  '##face': 670,
#  'compar': 671,
#  'commun': 672,
#  '##7': 673,
#  '##nel': 674,
#  'material': 675,
#  '##mer': 676,
#  '##ran': 677,
#  'energy': 678,
#  '##cor': 679,
#  '##W': 680,
#  '##und': 681,
#  'exten': 682,
#  'local': 683,
#  'pos': 684,
#  'adv': 685,
#  '##sure': 686,
#  'provide': 687,
#  'parameters': 688,
#  'novel': 689,
#  'algorithms': 690,
#  'applied': 691,
#  'how': 692,
#  '##ile': 693,
#  'lim': 694,
#  'tool': 695,
#  '##si': 696,
#  'effici': 697,
#  'flow': 698,
#  '##unt': 699,
#  'met': 700,
#  '##mal': 701,
#  '##eld': 702,
#  '##vol': 703,
#  '##ner': 704,
#  '##ep': 705,
#  'behavior': 706,
#  'there': 707,
#  'att': 708,
#  '##ue': 709,
#  'possi': 710,
#  'factor': 711,
#  '##su': 712,
#  'various': 713,
#  '##ation,': 714,
#  'sensor': 715,
#  'detection': 716,
#  'wh': 717,
#  'do': 718,
#  'require': 719,
#  '##sional': 720,
#  'For': 721,
#  'space': 722,
#  'predic': 723,
#  "##'": 724,
#  'analyz': 725,
#  '##tic': 726,
#  'clas': 727,
#  '##the': 728,
#  'feature': 729,
#  'St': 730,
#  'may': 731,
#  'K': 732,
#  '##cess': 733,
#  'respon': 734,
#  '##ong': 735,
#  'mo': 736,
#  'so': 737,
#  'reduc': 738,
#  'exper': 739,
#  'while': 740,
#  '##eg': 741,
#  '##me': 742,
#  '##ist': 743,
#  'emission': 744,
#  'mean': 745,
#  'case': 746,
#  '##ference': 747,
#  '##ber': 748,
#  'multiple': 749,
#  'term': 750,
#  'efficiency': 751,
#  'trac': 752,
#  'hand': 753,
#  'addition': 754,
#  '##vity': 755,
#  '##if': 756,
#  'many': 757,
#  'pres': 758,
#  '##ally,': 759,
#  'constra': 760,
#  '##ently': 761,
#  'optimal': 762,
#  '##ros': 763,
#  'then': 764,
#  'problems': 765,
#  '##ten': 766,
#  'ser': 767,
#  'networks': 768,
#  'temper': 769,
#  'main': 770,
#  'obser': 771,
#  'given': 772,
#  'Fin': 773,
#  'error': 774,
#  'distribution': 775,
#  'ag': 776,
#  'they': 777,
#  '##cy': 778,
#  '##ld': 779,
#  '##ined': 780,
#  'several': 781,
#  '##tern': 782,
#  'signal': 783,
#  'corre': 784,
#  'students': 785,
#  'allow': 786,
#  '##fy': 787,
#  'motion': 788,
#  'current': 789,
#  '##ages': 790,
#  '##for': 791,
#  '##ential': 792,
#  '##duc': 793,
#  'controller': 794,
#  '##ulated': 795,
#  '##-l': 796,
#  'vehicles': 797,
#  'need': 798,
#  '##gen': 799,
#  '##ecti': 800,
#  'support': 801,
#  '##hy': 802,
#  '##ang': 803,
#  '##ced': 804,
#  'rate': 805,
#  '##ction': 806,
#  'util': 807,
#  '##rit': 808,
#  'gener': 809,
#  '##ines': 810,
#  '##ers': 811,
#  'conver': 812,
#  'indic': 813,
#  'quality': 814,
#  '##way': 815,
#  'multi': 816,
#  '##ress': 817,
#  '##ision': 818,
#  '##ath': 819,
#  'mechanism': 820,
#  'soft': 821,
#  'due': 822,
#  '##form': 823,
#  'pattern': 824,
#  'techniques': 825,
#  'develop': 826,
#  '##ace': 827,
#  '##fore': 828,
#  'linear': 829,
#  '##ole': 830,
#  'presents': 831,
#  '##ough': 832,
#  'effect': 833,
#  '##ore': 834,
#  'better': 835,
#  'load': 836,
#  '##es.': 837,
#  '##ward': 838,
#  'del': 839,
#  'dec': 840,
#  'single': 841,
#  'mod': 842,
#  'prediction': 843,
#  'fil': 844,
#  'sen': 845,
#  'optim': 846,
#  'theor': 847,
#  'non-': 848,
#  '##rat': 849,
#  'frequ': 850,
#  'existing': 851,
#  '##raph': 852,
#  'images': 853,
#  '##ges': 854,
#  '##mp': 855,
#  'ste': 856,
#  'numer': 857,
#  'inst': 858,
#  'buil': 859,
#  'ele': 860,
#  '##mar': 861,
#  '##izing': 862,
#  'wor': 863,
#  'recognition': 864,
#  'exp': 865,
#  'bas': 866,
#  'foc': 867,
#  '##omet': 868,
#  'infl': 869,
#  '##ak': 870,
#  '##ari': 871,
#  'properties': 872,
#  'conduc': 873,
#  'calc': 874,
#  '##ample': 875,
#  '##xim': 876,
#  'technolog': 877,
#  'As': 878,
#  'designed': 879,
#  '##ould': 880,
#  'stand': 881,
#  'pot': 882,
#  'impact': 883,
#  '##ause': 884,
#  '##ffic': 885,
#  '##ency': 886,
#  '##abil': 887,
#  'robust': 888,
#  '##den': 889,
#  'Th': 890,
#  '##ill': 891,
#  'about': 892,
#  '##te': 893,
#  '##jection': 894,
#  'accuracy': 895,
#  'servic': 896,
#  '##dent': 897,
#  'conditions': 898,
#  '##agement': 899,
#  '##amples': 900,
#  'technique': 901,
#  '##esel': 902,
#  'approache': 903,
#  'These': 904,
#  'asses': 905,
#  'demonstrate': 906,
#  'noise': 907,
#  'analy': 908,
#  'result': 909,
#  '##get': 910,
#  'concept': 911,
#  'very': 912,
#  '(S': 913,
#  '##isu': 914,
#  'dataset': 915,
#  '##-of': 916,
#  'search': 917,
#  'indust': 918,
#  'prob': 919,
#  '##cert': 920,
#  'top': 921,
#  'Al': 922,
#  'no': 923,
#  'minim': 924,
#  '##rip': 925,
#  '##fication': 926,
#  'acti': 927,
#  '##fied': 928,
#  'effective': 929,
#  'map': 930,
#  'act': 931,
#  'combustion': 932,
#  '##lin': 933,
#  '##linear': 934,
#  '##ks': 935,
#  'ke': 936,
#  '##ited': 937,
#  'machine': 938,
#  '##sh': 939,
#  '##port': 940,
#  '##ables': 941,
#  '##iver': 942,
#  '##low': 943,
#  'der': 944,
#  '##mpl': 945,
#  '##uring': 946,
#  '##ise': 947,
#  '##ging': 948,
#  'effectivenes': 949,
#  '##ane': 950,
#  'appro': 951,
#  'soc': 952,
#  '##ne': 953,
#  '##cale': 954,
#  '4': 955,
#  '##ish': 956,
#  'considered': 957,
#  '##ule': 958,
#  'suc': 959,
#  '##ific': 960,
#  '-': 961,
#  'selection': 962,
#  '##time': 963,
#  '##aly': 964,
#  '##"': 965,
#  'domain': 966,
#  'effects': 967,
#  '##ules': 968,
#  'ev': 969,
#  '##rin': 970,
#  '##ures': 971,
#  '##rop': 972,
#  '##ison': 973,
#  'contin': 974,
#  '##eve': 975,
#  '##he': 976,
#  '##tical': 977,
#  'loc': 978,
#  '##ason': 979,
#  'higher': 980,
#  '##sical': 981,
#  '##val': 982,
#  '"': 983,
#  'agent': 984,
#  '##vention': 985,
#  '##sump': 986,
#  '##asing': 987,
#  'ful': 988,
#  'mar': 989,
#  '##ribut': 990,
#  '##soc': 991,
#  '##cle': 992,
#  'hel': 993,
#  '##son': 994,
#  'secon': 995,
#  '##sis': 996,
#  '##ned': 997,
#  '##itect': 998,
#  '##ument': 999,
#  ...}

# %% [markdown]
# # 3. 학습 데이터 준비

# %%
files = glob(r"D:\BERT-based-Paper-Impact-Prediction\rsc\training_data\*.pickle")

eids = []
for file in files:
    with open(file, 'rb') as f:   
        df = pd.read_pickle(f)
        eids.extend(df.eid.tolist())
pickle.dump(eids, 'rsc/preparation_data/eids.pickle')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12108/3970863151.py in <module>
#       6         df = pd.read_pickle(f)
#       7         eids.extend(df.eid.tolist())
# ----> 8 pickle.dump(eids, 'rsc/preparation_data/eids.pickle')
#
# TypeError: file must have a 'write' attribute

# %%
pickle.load(eids, 'rsc/`preparation_data/eids.pickle')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12108/1043264646.py in <module>
# ----> 1 pickle.load(eids, 'rsc/preparation_data/eids.pickle')
#
# TypeError: load() takes exactly 1 positional argument (2 given)

# %%
eids
# Out:
# ['2-s2.0-77955927984',
#  '2-s2.0-77955926968',
#  '2-s2.0-77955926720',
#  '2-s2.0-77955926410',
#  '2-s2.0-77955926208',
#  '2-s2.0-77955926195',
#  '2-s2.0-77955924559',
#  '2-s2.0-77955924402',
#  '2-s2.0-77955924296',
#  '2-s2.0-77955923475',
#  '2-s2.0-77955921838',
#  '2-s2.0-77955921721',
#  '2-s2.0-77955921491',
#  '2-s2.0-77955920480',
#  '2-s2.0-77953364289',
#  '2-s2.0-77953364243',
#  '2-s2.0-77953362241',
#  '2-s2.0-77953361445',
#  '2-s2.0-77953360763',
#  '2-s2.0-77953359341',
#  '2-s2.0-77953359284',
#  '2-s2.0-77953359101',
#  '2-s2.0-77953359013',
#  '2-s2.0-77953358967',
#  '2-s2.0-77953358785',
#  '2-s2.0-77953358640',
#  '2-s2.0-77953357627',
#  '2-s2.0-77953356855',
#  '2-s2.0-77953356361',
#  '2-s2.0-77952675249',
#  '2-s2.0-77952675066',
#  '2-s2.0-77952674606',
#  '2-s2.0-77952674573',
#  '2-s2.0-77952673899',
#  '2-s2.0-77952673094',
#  '2-s2.0-77952673044',
#  '2-s2.0-77952669691',
#  '2-s2.0-77952669448',
#  '2-s2.0-77952669202',
#  '2-s2.0-77952668797',
#  '2-s2.0-77952668621',
#  '2-s2.0-77952293338',
#  '2-s2.0-77952293182',
#  '2-s2.0-77952290937',
#  '2-s2.0-77952290921',
#  '2-s2.0-77952290900',
#  '2-s2.0-77952290730',
#  '2-s2.0-77952290722',
#  '2-s2.0-77952290601',
#  '2-s2.0-77952290196',
#  '2-s2.0-77952289414',
#  '2-s2.0-77952289268',
#  '2-s2.0-77952288598',
#  '2-s2.0-77952288021',
#  '2-s2.0-77952253387',
#  '2-s2.0-76749096754',
#  '2-s2.0-76649136136',
#  '2-s2.0-76449118874',
#  '2-s2.0-76449115818',
#  '2-s2.0-76449115620',
#  '2-s2.0-76449114775',
#  '2-s2.0-76449113527',
#  '2-s2.0-76449111979',
#  '2-s2.0-76449101713',
#  '2-s2.0-76449099883',
#  '2-s2.0-76449095672',
#  '2-s2.0-76449091820',
#  '2-s2.0-75449120489',
#  '2-s2.0-75449116762',
#  '2-s2.0-75449105650',
#  '2-s2.0-75449105271',
#  '2-s2.0-75449100782',
#  '2-s2.0-75449100732',
#  '2-s2.0-75449095252',
#  '2-s2.0-75449094287',
#  '2-s2.0-69249232120',
#  '2-s2.0-69249219033',
#  '2-s2.0-69249218004',
#  '2-s2.0-69249216553',
#  '2-s2.0-69249215408',
#  '2-s2.0-69249208664',
#  '2-s2.0-69249202566',
#  '2-s2.0-69249188560',
#  '2-s2.0-69149093935',
#  '2-s2.0-69149088209',
#  '2-s2.0-68049135734',
#  '2-s2.0-67949102009',
#  '2-s2.0-67949102007',
#  '2-s2.0-67949094313',
#  '2-s2.0-67949092774',
#  '2-s2.0-67949086648',
#  '2-s2.0-67949085060',
#  '2-s2.0-67349285692',
#  '2-s2.0-67349278198',
#  '2-s2.0-67349277727',
#  '2-s2.0-67349266687',
#  '2-s2.0-67349232030',
#  '2-s2.0-67349217084',
#  '2-s2.0-67349215732',
#  '2-s2.0-67349194696',
#  '2-s2.0-67349190612',
#  '2-s2.0-67349190325',
#  '2-s2.0-67349167011',
#  '2-s2.0-67349140895',
#  '2-s2.0-67349136091',
#  '2-s2.0-67349114529',
#  '2-s2.0-67349109117',
#  '2-s2.0-67349091106',
#  '2-s2.0-61349195155',
#  '2-s2.0-61349162912',
#  '2-s2.0-61349146220',
#  '2-s2.0-61349144877',
#  '2-s2.0-61349140694',
#  '2-s2.0-61349136875',
#  '2-s2.0-61349123562',
#  '2-s2.0-61349092289',
#  '2-s2.0-61349088732',
#  '2-s2.0-58349118431',
#  '2-s2.0-58349116224',
#  '2-s2.0-58349113383',
#  '2-s2.0-58349113190',
#  '2-s2.0-58349101513',
#  '2-s2.0-58349096883',
#  '2-s2.0-58349096655',
#  '2-s2.0-52149090328',
#  '2-s2.0-52049125727',
#  '2-s2.0-52049123804',
#  '2-s2.0-52049123553',
#  '2-s2.0-52049115662',
#  '2-s2.0-52049102242',
#  '2-s2.0-52049094165',
#  '2-s2.0-52049083428',
#  '2-s2.0-45849139376',
#  '2-s2.0-45849138568',
#  '2-s2.0-45849132071',
#  '2-s2.0-45849131695',
#  '2-s2.0-45849105968',
#  '2-s2.0-45849103549',
#  '2-s2.0-45849090369',
#  '2-s2.0-44649163203',
#  '2-s2.0-44549088306',
#  '2-s2.0-44549083974',
#  '2-s2.0-44449139370',
#  '2-s2.0-44449121897',
#  '2-s2.0-44449113204',
#  '2-s2.0-44349180841',
#  '2-s2.0-44349155337',
#  '2-s2.0-44349152376',
#  '2-s2.0-44349138709',
#  '2-s2.0-44349125115',
#  '2-s2.0-44349111087',
#  '2-s2.0-44349109503',
#  '2-s2.0-44349103030',
#  '2-s2.0-44349091470',
#  '2-s2.0-38849194763',
#  '2-s2.0-38849168737',
#  '2-s2.0-38849150228',
#  '2-s2.0-38849150227',
#  '2-s2.0-38849140162',
#  '2-s2.0-38849139556',
#  '2-s2.0-38849135979',
#  '2-s2.0-38849120537',
#  '2-s2.0-38849109934',
#  '2-s2.0-38849099559',
#  '2-s2.0-38849085706',
#  '2-s2.0-38749098698',
#  '2-s2.0-38649127918',
#  '2-s2.0-38649114100',
#  '2-s2.0-38649102211',
#  '2-s2.0-38649097581',
#  '2-s2.0-35148845736',
#  '2-s2.0-35148837275',
#  '2-s2.0-35148824199',
#  '2-s2.0-35148820094',
#  '2-s2.0-34548444953',
#  '2-s2.0-34548437516',
#  '2-s2.0-34548418419',
#  '2-s2.0-34548410801',
#  '2-s2.0-34547132043',
#  '2-s2.0-34547118803',
#  '2-s2.0-34547118555',
#  '2-s2.0-34547114227',
#  '2-s2.0-34547108101',
#  '2-s2.0-34250028124',
#  '2-s2.0-34250012799',
#  '2-s2.0-34250012517',
#  '2-s2.0-34249983385',
#  '2-s2.0-34247603042',
#  '2-s2.0-34247592957',
#  '2-s2.0-34247571918',
#  '2-s2.0-33947316643',
#  '2-s2.0-33947261508',
#  '2-s2.0-33947207335',
#  '2-s2.0-33947201092',
#  '2-s2.0-33845902250',
#  '2-s2.0-33845895521',
#  '2-s2.0-33845892495',
#  '2-s2.0-33845869546',
#  '2-s2.0-33750370497',
#  '2-s2.0-33750338259',
#  '2-s2.0-33750333550',
#  '2-s2.0-33750314167',
#  '2-s2.0-33749371971',
#  '2-s2.0-33749365892',
#  '2-s2.0-33749341476',
#  '2-s2.0-33749319394',
#  '2-s2.0-33748433633',
#  '2-s2.0-33748433089',
#  '2-s2.0-33748430167',
#  '2-s2.0-33748429561',
#  '2-s2.0-33746380545',
#  '2-s2.0-33746377916',
#  '2-s2.0-33746343983',
#  '2-s2.0-33746341473',
#  '2-s2.0-33746332352',
#  '2-s2.0-33746325464',
#  '2-s2.0-33745672778',
#  '2-s2.0-33745657049',
#  '2-s2.0-33745647603',
#  '2-s2.0-85076041682',
#  '2-s2.0-33646810106',
#  '2-s2.0-33646808628',
#  '2-s2.0-33646804155',
#  '2-s2.0-33646803478',
#  '2-s2.0-33646792225',
#  '2-s2.0-33646763525',
#  '2-s2.0-33646762818',
#  '2-s2.0-24344508863',
#  '2-s2.0-24344486096',
#  '2-s2.0-24344460946',
#  '2-s2.0-24344456477',
#  '2-s2.0-24344437754',
#  '2-s2.0-23844513726',
#  '2-s2.0-23844461784',
#  '2-s2.0-23844456542',
#  '2-s2.0-19544394397',
#  '2-s2.0-19544389975',
#  '2-s2.0-19544385224',
#  '2-s2.0-19544381683',
#  '2-s2.0-19544363920',
#  '2-s2.0-13244289867',
#  '2-s2.0-13244272002',
#  '2-s2.0-13244265553',
#  '2-s2.0-13244262690',
#  '2-s2.0-78649622496',
#  '2-s2.0-78649617690',
#  '2-s2.0-78649612675',
#  '2-s2.0-78649598773',
#  '2-s2.0-78649571510',
#  '2-s2.0-78649560866',
#  '2-s2.0-78649549592',
#  '2-s2.0-78649542281',
#  '2-s2.0-78249286544',
#  '2-s2.0-78249284634',
#  '2-s2.0-78249283238',
#  '2-s2.0-78249279100',
#  '2-s2.0-78249262288',
#  '2-s2.0-78249261531',
#  '2-s2.0-78249259039',
#  '2-s2.0-78249256345',
#  '2-s2.0-78249255512',
#  '2-s2.0-78249254885',
#  '2-s2.0-78249250876',
#  '2-s2.0-78249247734',
#  '2-s2.0-78249246028',
#  '2-s2.0-78249233577',
#  '2-s2.0-77953353864',
#  '2-s2.0-77953353432',
#  '2-s2.0-77953346780',
#  '2-s2.0-77953335685',
#  '2-s2.0-77953331988',
#  '2-s2.0-77953330902',
#  '2-s2.0-77953330463',
#  '2-s2.0-77953329737',
#  '2-s2.0-77949646717',
#  '2-s2.0-77949642468',
#  '2-s2.0-77949641206',
#  '2-s2.0-77949637420',
#  '2-s2.0-77949634487',
#  '2-s2.0-77949628623',
#  '2-s2.0-77949627329',
#  '2-s2.0-77949622256',
#  '2-s2.0-77949620379',
#  '2-s2.0-77949616219',
#  '2-s2.0-77949609939',
#  '2-s2.0-77949605040',
#  '2-s2.0-77949592341',
#  '2-s2.0-77949590643',
#  '2-s2.0-77949579763',
#  '2-s2.0-70749154882',
#  '2-s2.0-70749136568',
#  '2-s2.0-70749129921',
#  '2-s2.0-70749122630',
#  '2-s2.0-70749120600',
#  '2-s2.0-70749115436',
#  '2-s2.0-70749108454',
#  '2-s2.0-70749101502',
#  '2-s2.0-70749095874',
#  '2-s2.0-70749094850',
#  '2-s2.0-70749092326',
#  '2-s2.0-70749088267',
#  '2-s2.0-70749087456',
#  '2-s2.0-70249141718',
#  '2-s2.0-70249141321',
#  '2-s2.0-70249134987',
#  '2-s2.0-70249134103',
#  '2-s2.0-70249131885',
#  '2-s2.0-70249129811',
#  '2-s2.0-70249118236',
#  '2-s2.0-70249112675',
#  '2-s2.0-70249104734',
#  '2-s2.0-70249104293',
#  '2-s2.0-70249097073',
#  '2-s2.0-70249092973',
#  '2-s2.0-70249091520',
#  '2-s2.0-70249090450',
#  '2-s2.0-70249090090',
#  '2-s2.0-67650155729',
#  '2-s2.0-67650146298',
#  '2-s2.0-67650115089',
#  '2-s2.0-67650115088',
#  '2-s2.0-67650110040',
#  '2-s2.0-67650102827',
#  '2-s2.0-67649628349',
#  '2-s2.0-67649607390',
#  '2-s2.0-67649600932',
#  '2-s2.0-67649583428',
#  '2-s2.0-67549137532',
#  '2-s2.0-67549132240',
#  '2-s2.0-67549129072',
#  '2-s2.0-67549124920',
#  '2-s2.0-67549116995',
#  '2-s2.0-67549115084',
#  '2-s2.0-67549106917',
#  '2-s2.0-67549105146',
#  '2-s2.0-67549096656',
#  '2-s2.0-85008065994',
#  '2-s2.0-85008063748',
#  '2-s2.0-85008054161',
#  '2-s2.0-85008050249',
#  '2-s2.0-85008014325',
#  '2-s2.0-67650146315',
#  '2-s2.0-67649102185',
#  '2-s2.0-67549084646',
#  '2-s2.0-62949231205',
#  '2-s2.0-62949211650',
#  '2-s2.0-62949156867',
#  '2-s2.0-62949146383',
#  '2-s2.0-62949141252',
#  '2-s2.0-62949138855',
#  '2-s2.0-62949111210',
#  '2-s2.0-62949097971',
#  '2-s2.0-62949097132',
#  '2-s2.0-56849130518',
#  '2-s2.0-56849127660',
#  '2-s2.0-56849118747',
#  '2-s2.0-56849111967',
#  '2-s2.0-56849111722',
#  '2-s2.0-56849096806',
#  '2-s2.0-56849088947',
#  '2-s2.0-56849087620',
#  '2-s2.0-47149116056',
#  '2-s2.0-47149112952',
#  '2-s2.0-47149109649',
#  '2-s2.0-47149108502',
#  '2-s2.0-47149095246',
#  '2-s2.0-47149094659',
#  '2-s2.0-47149093548',
#  '2-s2.0-45249116978',
#  '2-s2.0-45249112139',
#  '2-s2.0-45249110652',
#  '2-s2.0-45249103301',
#  '2-s2.0-45249098471',
#  '2-s2.0-45249097332',
#  '2-s2.0-56849092604',
#  '2-s2.0-43349108404',
#  '2-s2.0-43349105421',
#  '2-s2.0-43349101408',
#  '2-s2.0-43349100764',
#  '2-s2.0-43349099669',
#  '2-s2.0-43349098231',
#  '2-s2.0-43349095798',
#  '2-s2.0-43349091249',
#  '2-s2.0-43349088216',
#  '2-s2.0-43349083272',
#  '2-s2.0-39449136580',
#  '2-s2.0-39449129636',
#  '2-s2.0-39449127161',
#  '2-s2.0-39449123912',
#  '2-s2.0-39449118364',
#  '2-s2.0-39449114030',
#  '2-s2.0-39449106428',
#  '2-s2.0-39449104318',
#  '2-s2.0-39449100938',
#  '2-s2.0-39449084181',
#  '2-s2.0-40349116339',
#  '2-s2.0-40349114641',
#  '2-s2.0-40349108738',
#  '2-s2.0-40349096509',
#  '2-s2.0-40349094871',
#  '2-s2.0-40349094869',
#  '2-s2.0-40349091569',
#  '2-s2.0-40349089897',
#  '2-s2.0-40349089006',
#  '2-s2.0-40349089005',
#  '2-s2.0-85008025508',
#  '2-s2.0-34547998737',
#  '2-s2.0-34547998160',
#  '2-s2.0-34547984802',
#  '2-s2.0-34547980157',
#  '2-s2.0-34547975384',
#  '2-s2.0-34547973374',
#  '2-s2.0-34547970104',
#  '2-s2.0-34547965736',
#  '2-s2.0-34547964451',
#  '2-s2.0-34147219754',
#  '2-s2.0-34147191077',
#  '2-s2.0-34147190863',
#  '2-s2.0-34147188612',
#  '2-s2.0-34147181085',
#  '2-s2.0-34147173307',
#  '2-s2.0-34147141936',
#  '2-s2.0-34147140886',
#  '2-s2.0-34147137143',
#  '2-s2.0-34147131832',
#  '2-s2.0-34147108236',
#  '2-s2.0-34147096944',
#  '2-s2.0-34047271082',
#  '2-s2.0-34047266618',
#  '2-s2.0-34047266615',
#  '2-s2.0-33846826586',
#  '2-s2.0-33846811392',
#  '2-s2.0-33846781443',
#  '2-s2.0-33846649555',
#  '2-s2.0-33846646006',
#  '2-s2.0-33846612720',
#  '2-s2.0-33846608207',
#  '2-s2.0-33846595682',
#  '2-s2.0-33846569931',
#  '2-s2.0-33847764117',
#  '2-s2.0-33847755577',
#  '2-s2.0-33847749429',
#  '2-s2.0-33847739041',
#  '2-s2.0-33847734417',
#  '2-s2.0-33847724410',
#  '2-s2.0-33847701763',
#  '2-s2.0-33847697024',
#  '2-s2.0-33847696220',
#  '2-s2.0-34147147034',
#  '2-s2.0-85008048517',
#  '2-s2.0-85008040387',
#  '2-s2.0-78249284958',
#  '2-s2.0-78249273283',
#  '2-s2.0-78249246776',
#  '2-s2.0-78249238171',
#  '2-s2.0-77955042240',
#  '2-s2.0-77955036828',
#  '2-s2.0-77955035291',
#  '2-s2.0-77955032685',
#  '2-s2.0-77955030197',
#  '2-s2.0-77955028067',
#  '2-s2.0-77955026294',
#  '2-s2.0-77951969253',
#  '2-s2.0-77951968146',
#  '2-s2.0-77951963597',
#  '2-s2.0-77951960516',
#  '2-s2.0-77951946519',
#  '2-s2.0-77951942943',
#  '2-s2.0-77149164441',
#  '2-s2.0-77149147434',
#  '2-s2.0-77149132751',
#  '2-s2.0-77149130190',
#  '2-s2.0-77149121766',
#  '2-s2.0-71049174072',
#  '2-s2.0-71049155751',
#  '2-s2.0-71049150013',
#  '2-s2.0-70349135923',
#  '2-s2.0-70349126729',
#  '2-s2.0-70349113524',
#  '2-s2.0-70349099609',
#  '2-s2.0-70349501971',
#  '2-s2.0-70349495874',
#  '2-s2.0-70349495871',
#  '2-s2.0-70349105990',
#  '2-s2.0-71049126080',
#  '2-s2.0-61449237448',
#  '2-s2.0-61449230854',
#  '2-s2.0-61449175952',
#  '2-s2.0-61449125105',
#  '2-s2.0-61449118957',
#  '2-s2.0-55849143639',
#  '2-s2.0-55849130342',
#  '2-s2.0-55849109631',
#  '2-s2.0-55849107776',
#  '2-s2.0-55849099612',
#  '2-s2.0-55849096940',
#  '2-s2.0-49249111403',
#  '2-s2.0-49249109552',
#  '2-s2.0-49249108382',
#  '2-s2.0-49249101937',
#  '2-s2.0-49249101709',
#  '2-s2.0-49249099314',
#  '2-s2.0-47649097595',
#  '2-s2.0-47549093183',
#  '2-s2.0-47549089514',
#  '2-s2.0-47549089301',
#  '2-s2.0-39049160615',
#  '2-s2.0-39049127449',
#  '2-s2.0-39049090457',
#  '2-s2.0-39049083864',
#  '2-s2.0-35649018261',
#  '2-s2.0-35648988597',
#  '2-s2.0-35648978558',
#  '2-s2.0-35648960391',
#  '2-s2.0-34547350774',
#  '2-s2.0-34547318893',
#  '2-s2.0-34547313689',
#  '2-s2.0-34547307351',
#  '2-s2.0-34547242417',
#  '2-s2.0-34247889923',
#  '2-s2.0-34247881825',
#  '2-s2.0-34247855786',
#  '2-s2.0-34247844343',
#  '2-s2.0-33847171446',
#  '2-s2.0-33847152135',
#  '2-s2.0-33847144078',
#  '2-s2.0-33847105482',
#  '2-s2.0-33750602632',
#  '2-s2.0-33750597903',
#  '2-s2.0-33750593957',
#  '2-s2.0-33750588632',
#  '2-s2.0-33746860294',
#  '2-s2.0-33746855433',
#  '2-s2.0-33746795389',
#  '2-s2.0-33746783340',
#  '2-s2.0-33646266714',
#  '2-s2.0-33646260668',
#  '2-s2.0-33646234211',
#  '2-s2.0-33646233770',
#  '2-s2.0-33745003924',
#  '2-s2.0-33744998485',
#  '2-s2.0-33744992946',
#  '2-s2.0-33744986039',
#  '2-s2.0-33744980676',
#  '2-s2.0-33744977463',
#  '2-s2.0-27644562655',
#  '2-s2.0-27644537457',
#  '2-s2.0-27644509577',
#  '2-s2.0-27644457727',
#  '2-s2.0-27644441861',
#  '2-s2.0-25444502620',
#  '2-s2.0-25444478324',
#  '2-s2.0-25444449022',
#  '2-s2.0-25444445558',
#  '2-s2.0-23244467753',
#  '2-s2.0-23244456817',
#  '2-s2.0-23244456101',
#  '2-s2.0-23244441667',
#  '2-s2.0-23244441447',
#  '2-s2.0-21944454762',
#  '2-s2.0-21944438086',
#  '2-s2.0-21944437955',
#  '2-s2.0-21944434851',
#  '2-s2.0-21944432063',
#  '2-s2.0-77957681392',
#  '2-s2.0-77957678331',
#  '2-s2.0-77957671247',
#  '2-s2.0-77957665577',
#  '2-s2.0-77957662525',
#  '2-s2.0-77957654832',
#  '2-s2.0-77957653047',
#  '2-s2.0-77955560788',
#  '2-s2.0-77955560785',
#  '2-s2.0-77955560302',
#  '2-s2.0-77955558640',
#  '2-s2.0-77955558334',
#  '2-s2.0-77955553264',
#  '2-s2.0-77955549486',
#  '2-s2.0-77955279919',
#  '2-s2.0-77955278616',
#  '2-s2.0-77955276751',
#  '2-s2.0-77955275667',
#  '2-s2.0-77955274519',
#  '2-s2.0-77955273251',
#  '2-s2.0-77955271622',
#  '2-s2.0-77955669813',
#  '2-s2.0-77955281091',
#  '2-s2.0-77955277214',
#  '2-s2.0-77955276929',
#  '2-s2.0-77955267869',
#  '2-s2.0-77955231919',
#  '2-s2.0-77955230755',
#  '2-s2.0-77955228103',
#  '2-s2.0-77955227066',
#  '2-s2.0-77955221097',
#  '2-s2.0-77955185484',
#  '2-s2.0-77951068185',
#  '2-s2.0-77950689764',
#  '2-s2.0-77950689573',
#  '2-s2.0-77950596573',
#  '2-s2.0-77950596137',
#  '2-s2.0-77950595957',
#  '2-s2.0-77950595216',
#  '2-s2.0-77950593651',
#  '2-s2.0-77149173450',
#  '2-s2.0-77149163343',
#  '2-s2.0-77149127382',
#  '2-s2.0-76949106049',
#  '2-s2.0-76949105775',
#  '2-s2.0-76949102292',
#  '2-s2.0-76949101936',
#  '2-s2.0-76949096848',
#  '2-s2.0-76949095944',
#  '2-s2.0-76949094073',
#  '2-s2.0-76949093873',
#  '2-s2.0-76949093524',
#  '2-s2.0-76949093343',
#  '2-s2.0-76949093193',
#  '2-s2.0-76949087986',
#  '2-s2.0-76949084017',
#  '2-s2.0-75449112584',
#  '2-s2.0-75449103518',
#  '2-s2.0-75249107806',
#  '2-s2.0-75249103030',
#  '2-s2.0-75249102390',
#  '2-s2.0-75249101301',
#  '2-s2.0-75249099139',
#  '2-s2.0-75249095604',
#  '2-s2.0-75249092007',
#  '2-s2.0-75249089281',
#  '2-s2.0-75249087621',
#  '2-s2.0-73549113072',
#  '2-s2.0-73349128083',
#  '2-s2.0-73249153409',
#  '2-s2.0-73249152966',
#  '2-s2.0-73249152378',
#  '2-s2.0-73249151570',
#  '2-s2.0-73249148631',
#  '2-s2.0-73249146628',
#  '2-s2.0-73249146441',
#  '2-s2.0-73249141341',
#  '2-s2.0-73249136027',
#  '2-s2.0-73249120767',
#  '2-s2.0-70849110706',
#  '2-s2.0-70849099349',
#  '2-s2.0-70849098249',
#  '2-s2.0-70849097664',
#  '2-s2.0-70649115525',
#  '2-s2.0-70649112290',
#  '2-s2.0-70649112288',
#  '2-s2.0-70649107752',
#  '2-s2.0-70649105566',
#  '2-s2.0-70649099952',
#  '2-s2.0-70649085001',
#  '2-s2.0-72149097077',
#  '2-s2.0-71849119791',
#  '2-s2.0-71849114498',
#  '2-s2.0-71849108484',
#  '2-s2.0-71849105929',
#  '2-s2.0-71849099876',
#  '2-s2.0-71849092706',
#  '2-s2.0-71849090147',
#  '2-s2.0-71849087159',
#  '2-s2.0-71849086575',
#  '2-s2.0-77955228769',
#  '2-s2.0-77950861641',
#  '2-s2.0-76949086324',
#  '2-s2.0-71849109001',
#  '2-s2.0-70349987598',
#  '2-s2.0-70349829654',
#  '2-s2.0-70349820495',
#  '2-s2.0-70349820383',
#  '2-s2.0-70349820367',
#  '2-s2.0-70349820045',
#  '2-s2.0-70349808016',
#  '2-s2.0-70349799006',
#  '2-s2.0-70349798837',
#  '2-s2.0-70349795750',
#  '2-s2.0-70349789292',
#  '2-s2.0-69349085327',
#  '2-s2.0-69249221344',
#  '2-s2.0-69249217798',
#  '2-s2.0-69249216431',
#  '2-s2.0-69249215235',
#  '2-s2.0-69249215219',
#  '2-s2.0-69249213471',
#  '2-s2.0-69249211013',
#  '2-s2.0-69249205470',
#  '2-s2.0-68149175162',
#  '2-s2.0-68149106044',
#  '2-s2.0-67650506823',
#  '2-s2.0-67650450180',
#  '2-s2.0-67650167720',
#  '2-s2.0-67650163443',
#  '2-s2.0-67650163436',
#  '2-s2.0-67650158391',
#  '2-s2.0-67650154186',
#  '2-s2.0-67650148003',
#  '2-s2.0-67650147970',
#  '2-s2.0-67650140628',
#  '2-s2.0-67650127083',
#  '2-s2.0-67650113597',
#  '2-s2.0-67650111667',
#  '2-s2.0-67650104345',
#  '2-s2.0-67650104296',
#  '2-s2.0-67349266210',
#  '2-s2.0-67349261795',
#  '2-s2.0-67349248691',
#  '2-s2.0-67349240725',
#  '2-s2.0-67349179609',
#  '2-s2.0-67349136346',
#  '2-s2.0-67349134162',
#  '2-s2.0-67349117282',
#  '2-s2.0-67349087426',
#  '2-s2.0-67349203568',
#  '2-s2.0-67349118881',
#  '2-s2.0-64749113662',
#  '2-s2.0-64749106147',
#  '2-s2.0-64749093372',
#  '2-s2.0-64749090568',
#  '2-s2.0-64749086686',
#  '2-s2.0-64749084122',
#  '2-s2.0-61749102654',
#  '2-s2.0-61749095689',
#  '2-s2.0-61749090402',
#  '2-s2.0-61449221819',
#  '2-s2.0-61449207011',
#  '2-s2.0-61449148368',
#  '2-s2.0-61449144377',
#  '2-s2.0-61449097425',
#  '2-s2.0-61449085431',
#  '2-s2.0-61349195791',
#  '2-s2.0-60749101770',
#  '2-s2.0-60649116931',
#  '2-s2.0-60649113014',
#  '2-s2.0-60649112832',
#  '2-s2.0-60649111050',
#  '2-s2.0-60649106144',
#  '2-s2.0-60649106134',
#  '2-s2.0-60649088235',
#  '2-s2.0-60649087121',
#  '2-s2.0-59849119575',
#  '2-s2.0-59849094403',
#  '2-s2.0-59849088731',
#  '2-s2.0-59749096591',
#  '2-s2.0-59749085758',
#  '2-s2.0-59649110456',
#  '2-s2.0-59649100219',
#  '2-s2.0-59649100166',
#  '2-s2.0-59649097440',
#  '2-s2.0-59649093865',
#  '2-s2.0-59649083655',
#  '2-s2.0-59649083654',
#  '2-s2.0-58649120797',
#  '2-s2.0-58649110581',
#  '2-s2.0-58649107880',
#  '2-s2.0-58649100899',
#  '2-s2.0-58649085484',
#  '2-s2.0-58249141214',
#  '2-s2.0-58249139451',
#  '2-s2.0-58249131362',
#  '2-s2.0-58249127282',
#  '2-s2.0-57749206648',
#  '2-s2.0-57749202042',
#  '2-s2.0-57749172253',
#  '2-s2.0-57649240476',
#  '2-s2.0-57649232738',
#  '2-s2.0-57649219996',
#  '2-s2.0-57649210711',
#  '2-s2.0-57649200677',
#  '2-s2.0-57649195598',
#  '2-s2.0-57649194766',
#  '2-s2.0-57649188960',
#  '2-s2.0-57649187929',
#  '2-s2.0-57649183930',
#  '2-s2.0-57649176864',
#  '2-s2.0-57649159154',
#  '2-s2.0-57649138978',
#  '2-s2.0-57649135374',
#  '2-s2.0-57649124404',
#  '2-s2.0-57649111988',
#  '2-s2.0-57549117478',
#  '2-s2.0-57549115992',
#  '2-s2.0-57549115811',
#  '2-s2.0-57549107923',
#  '2-s2.0-57549106863',
#  '2-s2.0-57549104902',
#  '2-s2.0-57549100898',
#  '2-s2.0-57549100264',
#  '2-s2.0-57549098437',
#  '2-s2.0-57549097113',
#  '2-s2.0-57549096945',
#  '2-s2.0-57549091437',
#  '2-s2.0-57549087978',
#  '2-s2.0-57549086891',
#  '2-s2.0-57449122137',
#  '2-s2.0-67349153064',
#  '2-s2.0-64749111942',
#  '2-s2.0-60649097311',
#  '2-s2.0-57349197313',
#  '2-s2.0-57349191628',
#  '2-s2.0-57149146594',
#  '2-s2.0-57149145925',
#  '2-s2.0-57149140923',
#  '2-s2.0-57149136183',
#  '2-s2.0-57149135775',
#  '2-s2.0-57149135103',
#  '2-s2.0-57149133681',
#  '2-s2.0-57149132694',
#  '2-s2.0-57149130453',
#  '2-s2.0-57149129599',
#  '2-s2.0-57149129002',
#  '2-s2.0-57149128753',
#  '2-s2.0-57149128627',
#  '2-s2.0-57149125730',
#  '2-s2.0-57149125045',
#  '2-s2.0-57049179703',
#  '2-s2.0-57049163646',
#  '2-s2.0-57049146451',
#  '2-s2.0-57049135296',
#  '2-s2.0-57049134155',
#  '2-s2.0-57049117994',
#  '2-s2.0-57049100412',
#  '2-s2.0-56949108666',
#  '2-s2.0-56949108153',
#  '2-s2.0-56949107873',
#  '2-s2.0-56949107609',
#  '2-s2.0-56949107479',
#  '2-s2.0-56949107328',
#  '2-s2.0-56949107086',
#  '2-s2.0-56949106653',
#  '2-s2.0-56949106504',
#  '2-s2.0-56949106348',
#  '2-s2.0-56949106220',
#  '2-s2.0-56949105840',
#  '2-s2.0-56949105686',
#  '2-s2.0-56949105286',
#  '2-s2.0-56949104938',
#  '2-s2.0-56949104815',
#  '2-s2.0-56949104195',
#  '2-s2.0-56949103913',
#  '2-s2.0-56949102758',
#  '2-s2.0-56949102362',
#  '2-s2.0-56949102361',
#  '2-s2.0-56949102360',
#  '2-s2.0-56949102359',
#  '2-s2.0-56949102081',
#  '2-s2.0-56949101466',
#  '2-s2.0-56949100793',
#  '2-s2.0-56949100254',
#  '2-s2.0-56949098902',
#  '2-s2.0-56949098026',
#  '2-s2.0-56949096886',
#  '2-s2.0-56949095496',
#  '2-s2.0-56949095295',
#  '2-s2.0-56949095034',
#  '2-s2.0-56949094663',
#  '2-s2.0-56949094264',
#  '2-s2.0-56949093692',
#  '2-s2.0-56949093682',
#  '2-s2.0-56949093418',
#  '2-s2.0-56949093153',
#  '2-s2.0-56949092097',
#  '2-s2.0-56949091961',
#  '2-s2.0-56949091960',
#  '2-s2.0-56949091579',
#  '2-s2.0-56949091195',
#  '2-s2.0-56949090952',
#  '2-s2.0-56949090686',
#  '2-s2.0-56949090401',
#  '2-s2.0-56949089988',
#  '2-s2.0-56949089169',
#  '2-s2.0-56949088534',
#  '2-s2.0-56949088395',
#  '2-s2.0-56949087992',
#  '2-s2.0-56949087987',
#  '2-s2.0-56949087066',
#  '2-s2.0-56949087055',
#  '2-s2.0-56949087052',
#  '2-s2.0-56949086777',
#  '2-s2.0-56949086154',
#  '2-s2.0-56949085850',
#  '2-s2.0-56949085402',
#  '2-s2.0-56949085263',
#  '2-s2.0-56949085019',
#  '2-s2.0-56949084999',
#  '2-s2.0-56949084878',
#  '2-s2.0-56949084873',
#  '2-s2.0-56949084597',
#  '2-s2.0-56949084595',
#  '2-s2.0-56949083350',
#  '2-s2.0-45749147028',
#  '2-s2.0-48349141603',
#  '2-s2.0-48349140887',
#  '2-s2.0-48349135362',
#  '2-s2.0-48349123352',
#  '2-s2.0-48349122354',
#  '2-s2.0-48349122298',
#  '2-s2.0-48349121637',
#  '2-s2.0-48349121167',
#  '2-s2.0-48349113763',
#  '2-s2.0-48349108918',
#  '2-s2.0-48349100347',
#  '2-s2.0-48349096205',
#  '2-s2.0-48349089719',
#  '2-s2.0-48349085540',
#  '2-s2.0-44649184852',
#  '2-s2.0-44649154346',
#  '2-s2.0-44649152903',
#  '2-s2.0-44649140338',
#  '2-s2.0-44649136623',
#  '2-s2.0-44649123591',
#  '2-s2.0-44649123262',
#  '2-s2.0-44649106240',
#  '2-s2.0-43749117699',
#  '2-s2.0-43749116634',
#  '2-s2.0-43749102870',
#  '2-s2.0-43549126633',
#  '2-s2.0-43549122560',
#  '2-s2.0-43549121222',
#  '2-s2.0-43549120964',
#  '2-s2.0-43549120222',
#  '2-s2.0-43549117025',
#  '2-s2.0-43549112526',
#  '2-s2.0-43549106555',
#  '2-s2.0-43549101109',
#  '2-s2.0-43549098227',
#  '2-s2.0-43549097779',
#  '2-s2.0-43549089724',
#  '2-s2.0-43649098991',
#  '2-s2.0-43649098956',
#  '2-s2.0-43649093077',
#  '2-s2.0-43649091889',
#  '2-s2.0-43649083244',
#  '2-s2.0-43449134988',
#  '2-s2.0-43449133258',
#  '2-s2.0-43449130377',
#  '2-s2.0-43449124084',
#  '2-s2.0-43449121226',
#  '2-s2.0-43449118052',
#  '2-s2.0-43449114779',
#  '2-s2.0-43449113533',
#  '2-s2.0-43449112938',
#  '2-s2.0-43449108847',
#  '2-s2.0-43449108257',
#  '2-s2.0-43449107654',
#  '2-s2.0-43449104700',
#  '2-s2.0-43449095422',
#  '2-s2.0-43449093709',
#  '2-s2.0-43449091242',
#  '2-s2.0-43449085500',
#  '2-s2.0-43449084925',
#  '2-s2.0-40749151083',
#  '2-s2.0-40649123734',
#  '2-s2.0-40649108855',
#  '2-s2.0-40649104956',
#  '2-s2.0-40649102944',
#  '2-s2.0-40649098637',
#  '2-s2.0-40649096631',
#  '2-s2.0-39149101795',
#  '2-s2.0-38949217024',
#  '2-s2.0-38949211032',
#  '2-s2.0-38949209089',
#  '2-s2.0-38949183984',
#  '2-s2.0-38949167081',
#  '2-s2.0-38949140482',
#  '2-s2.0-38949139053',
#  '2-s2.0-38949138055',
#  '2-s2.0-38949125469',
#  '2-s2.0-38949115914',
#  '2-s2.0-38949098638',
#  '2-s2.0-38949093799',
#  '2-s2.0-38949083487',
#  '2-s2.0-38349195091',
#  '2-s2.0-38349188665',
#  '2-s2.0-38349182747',
#  '2-s2.0-38349165295',
#  '2-s2.0-38349164471',
#  '2-s2.0-38349135441',
#  '2-s2.0-38349126344',
#  '2-s2.0-38349123908',
#  '2-s2.0-38349115709',
#  '2-s2.0-38349091076',
#  '2-s2.0-36349012022',
#  '2-s2.0-36348981174',
#  '2-s2.0-36348944769',
#  '2-s2.0-36249028794',
#  '2-s2.0-36249029306',
#  '2-s2.0-36249021018',
#  '2-s2.0-36249009678',
#  '2-s2.0-36248972613',
#  '2-s2.0-36248954015',
#  '2-s2.0-36249014332',
#  '2-s2.0-36249013230',
#  '2-s2.0-36248980426',
#  '2-s2.0-36248976105',
#  '2-s2.0-36248949131',
#  '2-s2.0-56949093152',
#  '2-s2.0-56949091078',
#  '2-s2.0-36249012452',
#  ...]
